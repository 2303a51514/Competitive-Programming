# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51514/Competitive-Programming/blob/main/week-5.9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class DSU:
    def __init__(self, n):
        self.parent = list(range(n + 1))
        self.rank = [0] * (n + 1)

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        # Union by Rank
        root_x = self.find(x)
        root_y = self.find(y)

        if root_x != root_y:
            if self.rank[root_x] < self.rank[root_y]:
                self.parent[root_x] = root_y
            elif self.rank[root_x] > self.rank[root_y]:
                self.parent[root_y] = root_x
            else:
                self.parent[root_y] = root_x
                self.rank[root_x] += 1
n = int(input("Number of intersections: "))
m = int(input("Number of roads constructed: "))

dsu = DSU(n)

print("Enter roads (u v):")
for _ in range(m):
    u, v = map(int, input().split())
    dsu.union(u, v)

q = int(input("Number of connectivity queries: "))
print("Enter queries (u v):")

for _ in range(q):
    u, v = map(int, input().split())
    if dsu.find(u) == dsu.find(v):
        print("YES")
    else:
        print("NO")
# Out:
# Number of intersections: 8
# Number of roads constructed: 5
# Enter roads (u v):
# 1 2
# 2 3
# 4 5
# 6 7
# 5 6
# Number of connectivity queries: 3
# Enter queries (u v):
# 1 3
# YES
# 1 7
# NO
# 4 7
# YES
