# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51514/Competitive-Programming/blob/main/kth%20smallest%20number%20minheap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ---------- Min Heap Functions ----------

def swap(arr, i, j):
    arr[i], arr[j] = arr[j], arr[i]

def min_heapify(arr, n, i):
    smallest = i
    left = 2 * i + 1
    right = 2 * i + 2
    if left < n and arr[left] < arr[smallest]:
        smallest = left

    if right < n and arr[right] < arr[smallest]:
        smallest = right

    if smallest != i:
        swap(arr, i, smallest)
        min_heapify(arr, n, smallest)
def build_min_heap(arr):
    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        min_heapify(arr, n, i)
def extract_min(arr, n):
    root = arr[0]
    arr[0] = arr[n - 1]
    n -= 1
    min_heapify(arr, n, 0)
    return root, n
def kth_smallest(arr, k):
    n = len(arr)
    if k <= 0 or k > n:
        return None
    build_min_heap(arr)
    for _ in range(1, k):
        _, n = extract_min(arr, n)
    return arr[0]
n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))
k = int(input("Enter k: "))

result = kth_smallest(arr, k)

if result is not None:
    print(f"The {k}-th smallest element is {result}")
else:
    print("Invalid value of k")
# Out:
# Enter number of elements: 6
# Enter elements: 7 10 4 3 20 15
# Enter k: 3
# The 3-th smallest element is 7
